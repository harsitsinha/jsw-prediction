# %%
import requests
import os
import tabula
import pandas as pd
from datetime import datetime, timedelta
import gspread
from google.oauth2 import service_account
from google.oauth2.service_account import Credentials

# %%
def read_tables_from_url(url):
    response = requests.get(url)
    with open('temp.pdf', 'wb') as file:
        file.write(response.content)

    # Read tables from the PDF file
    tables = tabula.read_pdf('temp.pdf', pages='all', multiple_tables=True, stream=True, pandas_options={'header': None})

    # Remove the temporary PDF file
    os.remove('temp.pdf')

    return tables

# %%
# tables = read_tables_from_url("https://reporting.wrldc.in/dailyreports/PSP/2019/January/WRLDC_PSP_Report_31-01-2019.pdf")
# tables[1]

# %%
def preprocess_table(tables,date,states):
    date=date.strftime("%d-%m-%Y")

    # SOLVNG THE ISSUE OF DIFFERENT SPELLINGS OF CHHATTISGARH
    column_data = tables[1].iloc[:, 0].tolist()
    start_index = next((i for i, value in enumerate(column_data) if value in ["CHHATTISGARH", "CHHATISGARH"]), None)
    if start_index is not None:
        temp_table = tables[1].iloc[start_index:]
        temp_table = temp_table.reset_index(drop=True)
        temp_table[0][0] = "CHHATTISGARH"
    
    # SOLVING THE ISSUE OF DIFFERENT SPLITTNG OF MADHYA PRADESH IN DIFFERENT ROWS

    index = temp_table.index[temp_table[0] == "MADHYA"].values[0]
    temp_table.loc[index] = temp_table.loc[index+1]
    temp_table.drop([index+1,index+2],axis=0,inplace=True)
    temp_table = temp_table.reset_index(drop=True)
    temp_table[0][index]="MADHYA PRADESH"

    # EXPANDING THE COLUMNS READ AS SINGLE COLUMN

    temp_table.drop(columns=[3,4,5],axis=1,inplace=True)
    temp_table=temp_table.T.reset_index(drop=True).T
    temp_table[[2,3,4,5]]=temp_table[2].str.split(expand=True)

    # SOLVING PROBLEM OF DADAR AND NAGAR HAVELI AND DAMAN AND DIU COMBINED AS ONE IN RECENT YEARS

    if "DNHDDPDCL" not in temp_table.iloc[:, 0].values:
        temp_table.loc[1]=temp_table.loc[2]
        temp_table.drop([2,3],axis=0,inplace=True)
        temp_table = temp_table.reset_index(drop=True)
        for i in range(1,temp_table.shape[1]):
            if temp_table[i][1] == "-" or temp_table[i][2] == '-':
                temp_table[i][1]='-'
            else:
                temp_table[i][1]=float(temp_table[i][1])+float(temp_table[i][2])
        temp_table.drop(2,axis=0,inplace=True)
        temp_table=temp_table.reset_index(drop=True)
        temp_table[0][1]="DNHDDPDCL"

    # REMOVING UNNECESSARY ROWS

    index=[]
    index = [x for x, value in enumerate(temp_table.iloc[:, 0].tolist()) if value in ["AMNSIL", "ESIL", "Region"]]
    for i in index:
        temp_table.drop(i,axis=0,inplace=True)
    temp_table.reset_index(drop=True,inplace=True)

    temp_table.columns=['State','Thermal','Hydro','Wind','Solar','Others','Demand Met','Shortage']
    temp_table.insert(0,'Date',date)
    for index, row in temp_table.iterrows():
        state = row['State']
        if state not in states.keys():
            states[state] = pd.DataFrame(columns=temp_table.columns)
        states[state] = pd.concat([states[state], pd.DataFrame([row])], ignore_index=True)
    
    
    return states

# %%
# column_data = tables[1].iloc[:, 0].tolist()
# start_index = next((i for i, value in enumerate(column_data) if value in ["CHHATTISGARH", "CHHATISGARH"]), None)

# # Select the rows starting from the identified index
# if start_index is not None:
#     temp_table = tables[1].iloc[start_index:]
#     temp_table = temp_table.reset_index(drop=True)
#     temp_table[0][0] = "CHHATTISGARH"

# temp_table

# %%
# index = temp_table.index[temp_table[0] == "MADHYA"].values[0]
# temp_table.loc[index] = temp_table.loc[index+1]
# temp_table.drop([index+1,index+2],axis=0,inplace=True)
# temp_table = temp_table.reset_index(drop=True)
# temp_table[0][index]="MADHYA PRADESH"

# %%
# temp_table.drop(columns=[3,4,5],axis=1,inplace=True)
# temp_table=temp_table.T.reset_index(drop=True).T
# temp_table[[2,3,4,5]]=temp_table[2].str.split(expand=True)

# %%
# temp_table

# %%
# if "DNHDDPDCL" not in temp_table.iloc[:, 0].values:
#     temp_table.loc[1]=temp_table.loc[2]
#     temp_table.drop([2,3],axis=0,inplace=True)
#     temp_table = temp_table.reset_index(drop=True)
#     for i in range(1,temp_table.shape[1]):
#         if temp_table[i][1] == "-" or temp_table[i][2] == '-':
#             temp_table[i][1]='-'
#         else:
#             temp_table[i][1]=float(temp_table[i][1])+float(temp_table[i][2])
#     temp_table.drop(2,axis=0,inplace=True)
#     temp_table=temp_table.reset_index(drop=True)
#     temp_table[0][1]="DNHDDPDCL"

# %%
# index=[]
# index = [x for x, value in enumerate(temp_table.iloc[:, 0].tolist()) if value in ["AMNSIL", "ESIL", "Region"]]
# for i in index:
#     temp_table.drop(i,axis=0,inplace=True)
# temp_table.reset_index(drop=True,inplace=True)

# %%
months = ['January','February', 'March', 'April', 'May', 'June', 'July', 'August', 'September','October','November','December']
month_dict = {index + 1: month for index, month in enumerate(months)}

start_date = datetime(2019, 2, 19)  # Specify the start date
end_date = datetime(2019, 2, 21)  # Specify the end date

# %%
states={}
current_date = start_date
while current_date <= end_date:
    # https://reporting.wrldc.in/dailyreports/PSP/2023/May/WRLDC_PSP_Report_31-05-2023.pdf
    url=f'https://reporting.wrldc.in/dailyreports/PSP/{current_date.year}/{month_dict[current_date.month]}/WRLDC_PSP_Report_{current_date.strftime("%d-%m-%Y")}.pdf'
    tables=read_tables_from_url(url)
    preprocess_table(tables,current_date,states)
    current_date += timedelta(days=1)
# Out:
# Got stderr: Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (224) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (164) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (166) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (191) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (168) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (173) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (176) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (149) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (165) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (128) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (138) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (141) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (156) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (190) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (181) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (163) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (175) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (170) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (167) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (174) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (135) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (130) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (182) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (161) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (178) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (134) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (185) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (133) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (129) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (184) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (154) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (150) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (151) in font Times-Bold
# Jun 06, 2023 12:42:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (148) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 166 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 173 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 176 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 128 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 138 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 156 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 190 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 181 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 163 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 170 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 167 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 174 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 135 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 130 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 182 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 161 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 178 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 134 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 185 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 133 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 129 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 184 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 154 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 150 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 151 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:14 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 148 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (183) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (172) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 183 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 135 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 176 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 148 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 172 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 128 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 154 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 134 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 190 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:16 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 183 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 135 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 176 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 148 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 172 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 128 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 154 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 134 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 190 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 133 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 167 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 174 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 130 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 181 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 173 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 133 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 167 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 174 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:17 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 130 (.notdef) in font Times-Bold
#
# Got stderr: Jun 06, 2023 12:42:19 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (224) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (164) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (166) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (191) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (168) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (173) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (176) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (149) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (165) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (128) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (138) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (141) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (156) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (190) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (181) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (163) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (175) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (170) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (167) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (174) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (135) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (130) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (182) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (161) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (178) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (134) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (185) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (133) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (129) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (184) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (154) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (150) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (151) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (148) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 166 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 173 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 176 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 128 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 138 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 156 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 190 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 181 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 163 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 170 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 167 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 174 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 135 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 130 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 182 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 161 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 178 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 134 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 185 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 133 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 129 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 184 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 154 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 150 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 151 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:20 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 148 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (183) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (172) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 183 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 135 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 176 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 148 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 172 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 128 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 154 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 134 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 190 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 183 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 135 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 176 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 148 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 172 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 128 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 154 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 134 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 190 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 133 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 167 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 174 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 130 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 181 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:23 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 173 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 133 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 167 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 174 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:24 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 130 (.notdef) in font Times-Bold
#
# Got stderr: Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (224) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (164) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (166) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (191) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (168) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (173) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (176) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (149) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (165) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (128) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (138) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (141) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (156) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (190) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (181) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (163) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (175) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (170) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (167) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (174) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (135) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (130) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (182) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (161) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (178) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (134) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (185) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (133) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (129) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (184) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (154) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (150) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (151) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (148) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 166 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 173 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 176 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 128 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 138 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 156 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 190 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 181 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 163 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 170 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 167 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 174 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 135 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 130 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 182 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 161 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 178 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 134 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 185 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 133 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 129 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 184 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 154 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 150 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 151 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:27 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 148 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (183) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# WARNING: No Unicode mapping for .notdef (172) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 183 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 135 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 176 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 148 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 172 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 128 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 154 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 134 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 190 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:29 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 183 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 135 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 176 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 148 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 172 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 128 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 154 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 134 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 190 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 133 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 167 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 174 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 130 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 181 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 173 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 224 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 164 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 133 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 167 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 191 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 149 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 174 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 168 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 165 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 141 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 175 (.notdef) in font Times-Bold
# Jun 06, 2023 12:42:30 AM org.apache.pdfbox.rendering.Type1Glyph2D getPathForCharacterCode
# WARNING: No glyph for code 130 (.notdef) in font Times-Bold
